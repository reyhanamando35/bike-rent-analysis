# %%
# Notebook ini menggunakan data historis per jam dan bulan untuk 
# memprediksi permintaan penyewaan di masa depan melalui metode forecasting.

# Dengan memanfaatkan algoritma LightGBM, hasil prediksi akan ditampilkan 
# dalam bentuk grafik untuk mempermudah pemantauan tren permintaan.
